# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

data = pd.read_csv('cleaned_data_telecomchurn.csv')

# %%
data.head()
# Out:
#    Unnamed: 0 telecom_partner gender  age  age_decay_range  age_interval  \
# 0           0    Reliance Jio      F   25               20  Young Adults
# 1           1    Reliance Jio      F   55               50    Old Adults
# 2           2        Vodafone      F   57               50    Old Adults
# 3           3            BSNL      M   46               40    Old Adults
# 4           4            BSNL      F   26               20    Old Adults
#
#                state     city           region  registration_year  ...  \
# 0          Karnataka  Kolkata      South India               2020  ...
# 1            Mizoram   Mumbai  Northeast India               2020  ...
# 2  Arunachal Pradesh    Delhi  Northeast India               2020  ...
# 3         Tamil Nadu  Kolkata      South India               2020  ...
# 4            Tripura    Delhi  Northeast India               2020  ...
#
#    num_dependents  single or not  estimated_salary calls_made  \
# 0               4     Not single            124962         44
# 1               2     Not single            130556         62
# 2               0         Single            148828         49
# 3               1     Not single             38722         80
# 4               2     Not single             55098         78
#
#    calls_made_negative  sms_sent  sms_sent_negative  data_used  \
# 0                    0        45                  0        361
# 1                    0        39                  0       5973
# 2                    0        24                  0        193
# 3                    0        25                  0       9377
# 4                    0        15                  0       1393
#
#    data_used_negative  churn
# 0                   1      0
# 1                   0      0
# 2                   0      1
# 3                   0      1
# 4                   0      0
#
# [5 rows x 22 columns]
# Warning: Total number of columns (22) exceeds max_columns (20) limiting to first (20) columns.

# %%
data.info
# Out:
# <bound method DataFrame.info of         Unnamed: 0 telecom_partner gender  age  age_decay_range  age_interval  \
# 0                0    Reliance Jio      F   25               20  Young Adults
# 1                1    Reliance Jio      F   55               50    Old Adults
# 2                2        Vodafone      F   57               50    Old Adults
# 3                3            BSNL      M   46               40    Old Adults
# 4                4            BSNL      F   26               20    Old Adults
# ...            ...             ...    ...  ...              ...           ...
# 243548      243548          Airtel      F   28               20    Old Adults
# 243549      243549    Reliance Jio      F   52               50    Old Adults
# 243550      243550    Reliance Jio      M   59               50    Old Adults
# 243551      243551            BSNL      M   49               40    Old Adults
# 243552      243552            BSNL      F   37               30    Old Adults
#
#                     state       city           region  registration_year  ...  \
# 0               Karnataka    Kolkata      South India               2020  ...
# 1                 Mizoram     Mumbai  Northeast India               2020  ...
# 2       Arunachal Pradesh      Delhi  Northeast India               2020  ...
# 3              Tamil Nadu    Kolkata      South India               2020  ...
# 4                 Tripura      Delhi  Northeast India               2020  ...
# ...                   ...        ...              ...                ...  ...
# 243548            Mizoram    Kolkata  Northeast India               2023  ...
# 243549              Assam    Kolkata  Northeast India               2023  ...
# 243550            Tripura    Kolkata  Northeast India               2023  ...
# 243551     Madhya Pradesh    Kolkata    Central India               2023  ...
# 243552          Telangana  Hyderabad      South India               2023  ...
#
#         num_dependents  single or not  estimated_salary calls_made  \
# 0                    4     Not single            124962         44
# 1                    2     Not single            130556         62
# 2                    0         Single            148828         49
# 3                    1     Not single             38722         80
# 4                    2     Not single             55098         78
# ...                ...            ...               ...        ...
# 243548               3     Not single            130580         28
# 243549               0         Single             82393         80
# 243550               4     Not single             51298         26
# 243551               2     Not single             83981         80
# 243552               0         Single            144297         61
#
#         calls_made_negative  sms_sent  sms_sent_negative  data_used  \
# 0                         0        45                  0        361
# 1                         0        39                  0       5973
# 2                         0        24                  0        193
# 3                         0        25                  0       9377
# 4                         0        15                  0       1393
# ...                     ...       ...                ...        ...
# 243548                    0         9                  0       4102
# 243549                    0        45                  0       7521
# 243550                    0         4                  0       6547
# 243551                    0        15                  0       1125
# 243552                    0         7                  0       3384
#
#         data_used_negative  churn
# 0                        1      0
# 1                        0      0
# 2                        0      1
# 3                        0      1
# 4                        0      0
# ...                    ...    ...
# 243548                   0      0
# 243549                   0      0
# 243550                   0      0
# 243551                   0      0
# 243552                   0      0
#
# [243553 rows x 22 columns]>

# %%
from matplotlib import pyplot as plt
_df_11.plot(kind='scatter', x='num_dependents', y='estimated_salary', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
_df_3['num_dependents'].plot(kind='hist', bins=20, title='num_dependents')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
plt.subplot(1, 2, 2)
# Changed 'df' to 'data' to access the correct DataFrame
data['num_dependents'].value_counts().plot.pie(autopct='%1.1f%%', colors=sns.color_palette('pastel'))
plt.ylabel("")
plt.title("Proportion of num_dependents ")
plt.show()

# %%
sns.scatterplot(x='calls_made', y='single or not', hue='gender', data=data)
plt.title('calls made vs. Number of Dependents')
plt.show()

# %%
plt.figure(figsize=(12, 4))
# Pie chart (proportions)
plt.subplot(1, 2, 2)
df['num_dependents'].value_counts().plot.pie(autopct='%1.1f%%', colors=sns.color_palette('pastel'))
plt.ylabel("")
plt.title("Proportion of Dependents")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='num_dependents', y='estimated_salary', data=data)
plt.title('Estimated Salary vs. Number of Dependents')
plt.xlabel('Number of Dependents')
plt.ylabel('Estimated Salary')
plt.show()

# %%
df.plot(kind='scatter',x='num_dependents',y='estimated_salary')
plt.title('Estimated Salary vs. Number of Dependents')
plt.show()

# %%
sns.scatterplot(x='estimated_salary', y='num_dependents', hue='single or not', data=data) # Changed 'Estimated Salary' to 'estimated_salary'
plt.title('Estimated Salary vs. Number of Dependents')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)
